# %% [markdown]
# # **Introduction**
#
# This notebook is used to load and sort the results of the hyperparameter sweep.

# %% [markdown]
# # **Import Packages**
#
# This section imports necessary packages.

# %%
# import these:
import numpy as np
import os
import json
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # **Loading the Data**
#
# This section loads the data based on which model the user would like to evaluate.

# %%
# define the model:
models = ["GLIE_MC", "SARSA_0", "SARSA_L"]
model = models[2]

# get the path to the results:
sweep_path = os.path.join(os.getcwd(), "sweep_results", model)

# %% [markdown]
# With the path, we can now load each file:

# %%
# initialize results list:
results = []

for file in os.listdir(sweep_path):
    # consolidate into one path:
    file_path = os.path.join(sweep_path, file)
    
    # open:
    with open(file_path, 'r') as f:
        data = json.load(f)

        # flatten the JSON:
        match model:
            case "GLIE_MC":
                extracted_data = {
                    # training params:
                    "gamma" : data["params"]["gamma"],
                    "epsilon_decay" : data["params"]["epsilon_decay"],

                    # training metrics:
                    "success_rate" : data["metrics"]["success_rate"],
                    "avg_return" : data["metrics"]["avg_return"],
                    "avg_length" : data["metrics"]["avg_length"]
                }
            case "SARSA_0":
                extracted_data = {
                    # training params:
                    "gamma" : data["params"]["gamma"],
                    "epsilon_decay" : data["params"]["epsilon_decay"],
                    "alpha" : data["params"]["alpha"],

                    # training metrics:
                    "success_rate" : data["metrics"]["success_rate"],
                    "avg_return" : data["metrics"]["avg_return"],
                    "avg_length" : data["metrics"]["avg_length"]
                }
            case "SARSA_L":
                extracted_data = {
                    # training params:
                    "gamma" : data["params"]["gamma"],
                    "epsilon_decay" : data["params"]["epsilon_decay"],
                    "alpha" : data["params"]["alpha"],
                    "lambda" : data["params"]["lamb"],

                    # training metrics:
                    "success_rate" : data["metrics"]["success_rate"],
                    "avg_return" : data["metrics"]["avg_return"],
                    "avg_length" : data["metrics"]["avg_length"]
                }

        # append to list:
        results.append(extracted_data)

# turn into a pandas df:
results_df = pd.DataFrame(results)

# insert an identifier for models:
results_df.insert(0, 'model_name', [f'{model}_model_{index + 1}' for index, row in results_df.iterrows()])

# %% [markdown]
# Save consolidated results into a .csv:

# %%
# make consolidated file path:
consolidated_file_path = os.path.join(os.getcwd(), "sweep_results/consolidated_results", model + "_results.csv")
results_df.sort_values(by = "success_rate", ascending = False).to_csv(consolidated_file_path, index = False)

# %% [markdown]
# # **Visualizing the Results**
#
# This section sorts the consolidated results by the various metrics.

# %% [markdown]
# Sort the consolidated results by the highest success rate:

# %%
results_df.sort_values(by = "success_rate", ascending = False).head(10)
# Out:
#           model_name  gamma  epsilon_decay  alpha  success_rate  avg_return  \
# 8    SARSA_0_model_9   0.99   8.000000e-07   0.05          75.8       0.722
# 9   SARSA_0_model_10   0.99   8.000000e-07   0.10          74.1       0.743
# 10  SARSA_0_model_11   0.99   8.000000e-07   0.25          72.0       0.730
# 21  SARSA_0_model_22   0.90   8.000000e-07   0.10          70.4       0.734
# 4    SARSA_0_model_5   0.99   3.000000e-07   0.05          68.6       0.710
# 1    SARSA_0_model_2   0.99   2.000000e-07   0.10          64.0       0.643
# 17  SARSA_0_model_18   0.90   3.000000e-07   0.10          61.3       0.591
# 5    SARSA_0_model_6   0.99   3.000000e-07   0.10          57.9       0.608
# 6    SARSA_0_model_7   0.99   3.000000e-07   0.25          52.1       0.502
# 16  SARSA_0_model_17   0.90   3.000000e-07   0.05          41.7       0.395
#
#     avg_length
# 8       41.702
# 9       42.836
# 10      42.364
# 21      39.617
# 4       39.582
# 1       40.894
# 17      37.236
# 5       35.799
# 6       30.301
# 16      25.631

# %% [markdown]
# Sort the consolidated results by the highest average return:

# %%
results_df.sort_values(by = "avg_return", ascending = False).head(10)
# Out:
#           model_name  gamma  epsilon_decay  alpha  success_rate  avg_return  \
# 9   SARSA_0_model_10   0.99   8.000000e-07   0.10          74.1       0.743
# 21  SARSA_0_model_22   0.90   8.000000e-07   0.10          70.4       0.734
# 10  SARSA_0_model_11   0.99   8.000000e-07   0.25          72.0       0.730
# 8    SARSA_0_model_9   0.99   8.000000e-07   0.05          75.8       0.722
# 4    SARSA_0_model_5   0.99   3.000000e-07   0.05          68.6       0.710
# 1    SARSA_0_model_2   0.99   2.000000e-07   0.10          64.0       0.643
# 5    SARSA_0_model_6   0.99   3.000000e-07   0.10          57.9       0.608
# 17  SARSA_0_model_18   0.90   3.000000e-07   0.10          61.3       0.591
# 6    SARSA_0_model_7   0.99   3.000000e-07   0.25          52.1       0.502
# 12  SARSA_0_model_13   0.90   2.000000e-07   0.05          39.4       0.405
#
#     avg_length
# 9       42.836
# 21      39.617
# 10      42.364
# 8       41.702
# 4       39.582
# 1       40.894
# 5       35.799
# 17      37.236
# 6       30.301
# 12      35.723

# %% [markdown]
# Sort the consolidated results by the lowest average episode length:

# %%
results_df.sort_values(by = "avg_length", ascending = True).head(10)
# Out:
#           model_name  gamma  epsilon_decay  alpha  success_rate  avg_return  \
# 7    SARSA_0_model_8   0.99   3.000000e-07   0.50           7.2       0.086
# 19  SARSA_0_model_20   0.90   3.000000e-07   0.50          13.6       0.145
# 20  SARSA_0_model_21   0.90   8.000000e-07   0.05          20.0       0.207
# 13  SARSA_0_model_14   0.90   2.000000e-07   0.10          20.6       0.173
# 15  SARSA_0_model_16   0.90   2.000000e-07   0.50          13.8       0.121
# 18  SARSA_0_model_19   0.90   3.000000e-07   0.25          13.0       0.145
# 2    SARSA_0_model_3   0.99   2.000000e-07   0.25          19.2       0.192
# 14  SARSA_0_model_15   0.90   2.000000e-07   0.25          21.8       0.227
# 0    SARSA_0_model_1   0.99   2.000000e-07   0.05          35.5       0.341
# 16  SARSA_0_model_17   0.90   3.000000e-07   0.05          41.7       0.395
#
#     avg_length
# 7        7.184
# 19      10.841
# 20      13.834
# 13      14.954
# 15      16.794
# 18      18.864
# 2       19.313
# 14      19.329
# 0       23.747
# 16      25.631

# %% [markdown]
# Sort the consolidated results by the highest success rate, the highest average return, and the lowest average episode length:

# %%
results_df.sort_values(by = ["success_rate", "avg_return", "avg_length"], ascending = [False, False, True])
# Out:
#           model_name  gamma  epsilon_decay  alpha  success_rate  avg_return  \
# 8    SARSA_0_model_9   0.99   8.000000e-07   0.05          75.8       0.722
# 9   SARSA_0_model_10   0.99   8.000000e-07   0.10          74.1       0.743
# 10  SARSA_0_model_11   0.99   8.000000e-07   0.25          72.0       0.730
# 21  SARSA_0_model_22   0.90   8.000000e-07   0.10          70.4       0.734
# 4    SARSA_0_model_5   0.99   3.000000e-07   0.05          68.6       0.710
# 1    SARSA_0_model_2   0.99   2.000000e-07   0.10          64.0       0.643
# 17  SARSA_0_model_18   0.90   3.000000e-07   0.10          61.3       0.591
# 5    SARSA_0_model_6   0.99   3.000000e-07   0.10          57.9       0.608
# 6    SARSA_0_model_7   0.99   3.000000e-07   0.25          52.1       0.502
# 16  SARSA_0_model_17   0.90   3.000000e-07   0.05          41.7       0.395
# 12  SARSA_0_model_13   0.90   2.000000e-07   0.05          39.4       0.405
# 11  SARSA_0_model_12   0.99   8.000000e-07   0.50          38.7       0.346
# 0    SARSA_0_model_1   0.99   2.000000e-07   0.05          35.5       0.341
# 22  SARSA_0_model_23   0.90   8.000000e-07   0.25          32.3       0.300
# 23  SARSA_0_model_24   0.90   8.000000e-07   0.50          27.5       0.268
# 14  SARSA_0_model_15   0.90   2.000000e-07   0.25          21.8       0.227
# 13  SARSA_0_model_14   0.90   2.000000e-07   0.10          20.6       0.173
# 20  SARSA_0_model_21   0.90   8.000000e-07   0.05          20.0       0.207
# 2    SARSA_0_model_3   0.99   2.000000e-07   0.25          19.2       0.192
# 3    SARSA_0_model_4   0.99   2.000000e-07   0.50          18.9       0.187
# 15  SARSA_0_model_16   0.90   2.000000e-07   0.50          13.8       0.121
# 19  SARSA_0_model_20   0.90   3.000000e-07   0.50          13.6       0.145
# 18  SARSA_0_model_19   0.90   3.000000e-07   0.25          13.0       0.145
# 7    SARSA_0_model_8   0.99   3.000000e-07   0.50           7.2       0.086
#
#     avg_length
# 8       41.702
# 9       42.836
# 10      42.364
# 21      39.617
# 4       39.582
# 1       40.894
# 17      37.236
# 5       35.799
# 6       30.301
# 16      25.631
# 12      35.723
# 11      54.938
# 0       23.747
# 22      26.144
# 23      28.421
# 14      19.329
# 13      14.954
# 20      13.834
# 2       19.313
# 3       33.708
# 15      16.794
# 19      10.841
# 18      18.864
# 7        7.184
