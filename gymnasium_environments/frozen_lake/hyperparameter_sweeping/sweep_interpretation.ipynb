# %% [markdown]
# # **Introduction**
#
# This notebook is used to load and sort the results of the hyperparameter sweep.

# %% [markdown]
# # **Import Packages**
#
# This section imports necessary packages.

# %%
# import these:
import numpy as np
import os
import json
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # **Loading the Data**
#
# This section loads the data based on which model the user would like to evaluate.

# %%
# define the model:
models = ["GLIE_MC", "SARSA_0", "SARSA_L"]
model = models[2]

# get the path to the results:
sweep_path = os.path.join(os.getcwd(), "sweep_results", model)

# %% [markdown]
# With the path, we can now load each file:

# %%
# initialize results list:
results = []

for file in os.listdir(sweep_path):
    # consolidate into one path:
    file_path = os.path.join(sweep_path, file)
    
    # open:
    with open(file_path, 'r') as f:
        data = json.load(f)

        # flatten the JSON:
        match model:
            case "GLIE_MC":
                extracted_data = {
                    # training params:
                    "gamma" : data["params"]["gamma"],
                    "epsilon_decay" : data["params"]["epsilon_decay"],

                    # training metrics:
                    "success_rate" : data["metrics"]["success_rate"],
                    "avg_return" : data["metrics"]["avg_return"],
                    "avg_length" : data["metrics"]["avg_length"]
                }
            case "SARSA_0":
                extracted_data = {
                    # training params:
                    "gamma" : data["params"]["gamma"],
                    "epsilon_decay" : data["params"]["epsilon_decay"],
                    "alpha" : data["params"]["alpha"],

                    # training metrics:
                    "success_rate" : data["metrics"]["success_rate"],
                    "avg_return" : data["metrics"]["avg_return"],
                    "avg_length" : data["metrics"]["avg_length"]
                }
            case "SARSA_L":
                extracted_data = {
                    # training params:
                    "gamma" : data["params"]["gamma"],
                    "epsilon_decay" : data["params"]["epsilon_decay"],
                    "alpha" : data["params"]["alpha"],
                    "lambda" : data["params"]["lamb"],

                    # training metrics:
                    "success_rate" : data["metrics"]["success_rate"],
                    "avg_return" : data["metrics"]["avg_return"],
                    "avg_length" : data["metrics"]["avg_length"]
                }

        # append to list:
        results.append(extracted_data)

# turn into a pandas df:
results_df = pd.DataFrame(results)

# insert an identifier for models:
results_df.insert(0, 'model_name', [f'{model}_model_{index + 1}' for index, row in results_df.iterrows()])

# %% [markdown]
# Save consolidated results into a .csv:

# %%
# make consolidated file path:
consolidated_file_path = os.path.join(os.getcwd(), "sweep_results/consolidated_results", model + "_results.csv")
results_df.sort_values(by = "success_rate", ascending = False).to_csv(consolidated_file_path, index = False)

# %% [markdown]
# # **Visualizing the Results**
#
# This section sorts the consolidated results by the various metrics.

# %% [markdown]
# Sort the consolidated results by the highest success rate:

# %%
results_df.sort_values(by = "success_rate", ascending = False).head(10)
# Out:
#           model_name  gamma  epsilon_decay  alpha  lambda  success_rate  \
# 16  SARSA_L_model_17   0.99       0.000004   0.10    0.90          50.4
# 12  SARSA_L_model_13   0.99       0.000004   0.05    0.80          44.5
# 0    SARSA_L_model_1   0.99       0.000002   0.05    0.80          23.5
# 18  SARSA_L_model_19   0.90       0.000002   0.05    0.80          22.4
# 21  SARSA_L_model_22   0.90       0.000002   0.10    0.80          21.0
# 26  SARSA_L_model_27   0.90       0.000001   0.05    0.95          20.8
# 33  SARSA_L_model_34   0.90       0.000004   0.10    0.80          20.5
# 9   SARSA_L_model_10   0.99       0.000001   0.10    0.80          19.1
# 15  SARSA_L_model_16   0.99       0.000004   0.10    0.80          18.2
# 29  SARSA_L_model_30   0.90       0.000001   0.10    0.95          17.6
#
#     avg_return  avg_length
# 16       0.515      34.067
# 12       0.433      30.454
# 0        0.229      19.303
# 18       0.218      20.037
# 21       0.210      18.386
# 26       0.193      19.094
# 33       0.196      15.896
# 9        0.198      17.632
# 15       0.170      18.109
# 29       0.176      41.413

# %% [markdown]
# Sort the consolidated results by the highest average return:

# %%
results_df.sort_values(by = "avg_return", ascending = False).head(10)
# Out:
#           model_name  gamma  epsilon_decay  alpha  lambda  success_rate  \
# 16  SARSA_L_model_17   0.99       0.000004   0.10    0.90          50.4
# 12  SARSA_L_model_13   0.99       0.000004   0.05    0.80          44.5
# 0    SARSA_L_model_1   0.99       0.000002   0.05    0.80          23.5
# 18  SARSA_L_model_19   0.90       0.000002   0.05    0.80          22.4
# 21  SARSA_L_model_22   0.90       0.000002   0.10    0.80          21.0
# 9   SARSA_L_model_10   0.99       0.000001   0.10    0.80          19.1
# 33  SARSA_L_model_34   0.90       0.000004   0.10    0.80          20.5
# 26  SARSA_L_model_27   0.90       0.000001   0.05    0.95          20.8
# 29  SARSA_L_model_30   0.90       0.000001   0.10    0.95          17.6
# 15  SARSA_L_model_16   0.99       0.000004   0.10    0.80          18.2
#
#     avg_return  avg_length
# 16       0.515      34.067
# 12       0.433      30.454
# 0        0.229      19.303
# 18       0.218      20.037
# 21       0.210      18.386
# 9        0.198      17.632
# 33       0.196      15.896
# 26       0.193      19.094
# 29       0.176      41.413
# 15       0.170      18.109

# %% [markdown]
# Sort the consolidated results by the lowest average episode length:

# %%
results_df.sort_values(by = "avg_length", ascending = True).head(10)
# Out:
#           model_name  gamma  epsilon_decay  alpha  lambda  success_rate  \
# 35  SARSA_L_model_36   0.90       0.000004   0.10    0.95           3.4
# 8    SARSA_L_model_9   0.99       0.000001   0.05    0.95           0.0
# 1    SARSA_L_model_2   0.99       0.000002   0.05    0.90           2.7
# 6    SARSA_L_model_7   0.99       0.000001   0.05    0.80           9.1
# 27  SARSA_L_model_28   0.90       0.000001   0.10    0.80           4.5
# 10  SARSA_L_model_11   0.99       0.000001   0.10    0.90           6.1
# 11  SARSA_L_model_12   0.99       0.000001   0.10    0.95           4.8
# 32  SARSA_L_model_33   0.90       0.000004   0.05    0.95           3.6
# 13  SARSA_L_model_14   0.99       0.000004   0.05    0.90           2.1
# 7    SARSA_L_model_8   0.99       0.000001   0.05    0.90           7.0
#
#     avg_return  avg_length
# 35       0.041       5.501
# 8        0.000       5.949
# 1        0.018       6.136
# 6        0.077       6.599
# 27       0.059       6.643
# 10       0.081       7.711
# 11       0.048       7.821
# 32       0.044       8.000
# 13       0.012       8.039
# 7        0.066       8.532

# %% [markdown]
# Sort the consolidated results by the highest success rate, the highest average return, and the lowest average episode length:

# %%
results_df.sort_values(by = ["success_rate", "avg_return", "avg_length"], ascending = [False, False, True])
# Out:
#           model_name  gamma  epsilon_decay  alpha  lambda  success_rate  \
# 16  SARSA_L_model_17   0.99       0.000004   0.10    0.90          50.4
# 12  SARSA_L_model_13   0.99       0.000004   0.05    0.80          44.5
# 0    SARSA_L_model_1   0.99       0.000002   0.05    0.80          23.5
# 18  SARSA_L_model_19   0.90       0.000002   0.05    0.80          22.4
# 21  SARSA_L_model_22   0.90       0.000002   0.10    0.80          21.0
# 26  SARSA_L_model_27   0.90       0.000001   0.05    0.95          20.8
# 33  SARSA_L_model_34   0.90       0.000004   0.10    0.80          20.5
# 9   SARSA_L_model_10   0.99       0.000001   0.10    0.80          19.1
# 15  SARSA_L_model_16   0.99       0.000004   0.10    0.80          18.2
# 29  SARSA_L_model_30   0.90       0.000001   0.10    0.95          17.6
# 20  SARSA_L_model_21   0.90       0.000002   0.05    0.95          16.1
# 30  SARSA_L_model_31   0.90       0.000004   0.05    0.80          14.9
# 17  SARSA_L_model_18   0.99       0.000004   0.10    0.95          14.2
# 3    SARSA_L_model_4   0.99       0.000002   0.10    0.80          13.9
# 28  SARSA_L_model_29   0.90       0.000001   0.10    0.90          12.6
# 2    SARSA_L_model_3   0.99       0.000002   0.05    0.95          11.7
# 5    SARSA_L_model_6   0.99       0.000002   0.10    0.95          10.8
# 24  SARSA_L_model_25   0.90       0.000001   0.05    0.80          10.7
# 25  SARSA_L_model_26   0.90       0.000001   0.05    0.90          10.7
# 31  SARSA_L_model_32   0.90       0.000004   0.05    0.90          10.6
# 14  SARSA_L_model_15   0.99       0.000004   0.05    0.95          10.2
# 19  SARSA_L_model_20   0.90       0.000002   0.05    0.90           9.6
# 6    SARSA_L_model_7   0.99       0.000001   0.05    0.80           9.1
# 34  SARSA_L_model_35   0.90       0.000004   0.10    0.90           9.0
# 4    SARSA_L_model_5   0.99       0.000002   0.10    0.90           8.7
# 7    SARSA_L_model_8   0.99       0.000001   0.05    0.90           7.0
# 10  SARSA_L_model_11   0.99       0.000001   0.10    0.90           6.1
# 22  SARSA_L_model_23   0.90       0.000002   0.10    0.90           5.9
# 23  SARSA_L_model_24   0.90       0.000002   0.10    0.95           5.8
# 11  SARSA_L_model_12   0.99       0.000001   0.10    0.95           4.8
# 27  SARSA_L_model_28   0.90       0.000001   0.10    0.80           4.5
# 32  SARSA_L_model_33   0.90       0.000004   0.05    0.95           3.6
# 35  SARSA_L_model_36   0.90       0.000004   0.10    0.95           3.4
# 1    SARSA_L_model_2   0.99       0.000002   0.05    0.90           2.7
# 13  SARSA_L_model_14   0.99       0.000004   0.05    0.90           2.1
# 8    SARSA_L_model_9   0.99       0.000001   0.05    0.95           0.0
#
#     avg_return  avg_length
# 16       0.515      34.067
# 12       0.433      30.454
# 0        0.229      19.303
# 18       0.218      20.037
# 21       0.210      18.386
# 26       0.193      19.094
# 33       0.196      15.896
# 9        0.198      17.632
# 15       0.170      18.109
# 29       0.176      41.413
# 20       0.144      17.075
# 30       0.144      14.279
# 17       0.124      12.365
# 3        0.138      10.288
# 28       0.122      28.742
# 2        0.106       8.817
# 5        0.108      17.411
# 24       0.121      10.246
# 25       0.099       8.698
# 31       0.116      10.023
# 14       0.107      10.348
# 19       0.114      17.402
# 6        0.077       6.599
# 34       0.110       9.642
# 4        0.080       8.590
# 7        0.066       8.532
# 10       0.081       7.711
# 22       0.054      10.437
# 23       0.049      12.989
# 11       0.048       7.821
# 27       0.059       6.643
# 32       0.044       8.000
# 35       0.041       5.501
# 1        0.018       6.136
# 13       0.012       8.039
# 8        0.000       5.949
